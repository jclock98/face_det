# %%
# !git clone https://github.com/ultralytics/yolov5  # clone repo
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 19, done.
# remote: Counting objects: 100% (19/19), done.
# remote: Compressing objects: 100% (14/14), done.
# remote: Total 2508 (delta 7), reused 14 (delta 5), pack-reused 2489
# Receiving objects: 100% (2508/2508), 5.37 MiB | 8.87 MiB/s, done.
# Resolving deltas: 100% (1644/1644), done.

# %%
# !pip install -qr yolov5/requirements.txt
# Out:
#      |████████████████████████████████| 276kB 6.9MB/s
# ...

# %%
# !ln -s "/content/drive/My Drive" /gdrive

# %%
# !unzip /gdrive/Colab_Notebooks/DataMantix/Face_Detection/WiderFace.zip -d yolov5/data
# Out:
# Output streaming troncato alle ultime 5000 righe.
#   inflating: yolov5/data/WiderFace/labels/train/2_Demonstration_Political_Rally_2_450.txt
#   inflating: yolov5/data/WiderFace/labels/train/55_Sports_Coach_Trainer_sportcoaching_55_72.txt
#   inflating: yolov5/data/WiderFace/labels/train/39_Ice_Skating_iceskiing_39_43.txt
#   inflating: yolov5/data/WiderFace/labels/train/47_Matador_Bullfighter_Matador_Bullfighter_47_876.txt
#   inflating: yolov5/data/WiderFace/labels/train/2_Demonstration_Political_Rally_2_336.txt
#   inflating: yolov5/data/WiderFace/labels/train/52_Photographers_taketouristphotos_52_211.txt
#   inflating: yolov5/data/WiderFace/labels/train/55_Sports_Coach_Trainer_sportcoaching_55_611.txt
#   inflating: yolov5/data/WiderFace/labels/train/50_Celebration_Or_Party_houseparty_50_880.txt
#   inflating: yolov5/data/WiderFace/labels/train/16_Award_Ceremony_Awards_Ceremony_16_304.txt
#   inflating: yolov5/data/WiderFace/labels/train/58_Hockey_icehockey_puck_58_141.txt
# ...

# %%
# !ls -d yolov5/data/WiderFace/images/train/* > yolov5/data/WiderFace/train.txt

# %%
# !ls -d yolov5/data/WiderFace/images/valid/* > yolov5/data/WiderFace/valid.txt

# %%
# !ls -d yolov5/data/WiderFace/images/test/* > yolov5/data/WiderFace/test.txt

# %%
# !python /content/yolov5/train.py --img 640 --batch 16 --epochs 30 --data /content/yolov5/data/WiderFace/face.yaml --cfg /content/yolov5/models/yolov5m.yaml --weights '' --device 0
# Out:
# Using CUDA device0 _CudaDeviceProperties(name='Tesla K80', total_memory=11441MB)
#
# Namespace(adam=False, batch_size=16, bucket='', cache_images=False, cfg='/content/yolov5/models/yolov5m.yaml', data='/content/yolov5/data/WiderFace/face.yaml', device='0', epochs=30, evolve=False, global_rank=-1, hyp='./yolov5/data/hyp.scratch.yaml', image_weights=False, img_size=[640, 640], local_rank=-1, logdir='runs/', multi_scale=False, name='', noautoanchor=False, nosave=False, notest=False, rect=False, resume=False, single_cls=False, sync_bn=False, total_batch_size=16, weights='', workers=8, world_size=1)
# Start Tensorboard with "tensorboard --logdir runs/", view at http://localhost:6006/
# 2020-09-11 13:46:56.244300: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# ...
